# %% [markdown]
# # Task 3
# ## Classifying male and female names

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Gargi')
# Out:
# {'last_letter': 'i'}

# %%
from nltk.corpus import names

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])

# %%
labeled_names
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male'),
#  ('Abdullah', 'male'),
#  ('Abe', 'male'),
#  ('Abel', 'male'),
#  ('Abelard', 'male'),
#  ('Abner', 'male'),
#  ('Abraham', 'male'),
#  ('Abram', 'male'),
#  ('Ace', 'male'),
#  ('Adair', 'male'),
#  ('Adam', 'male'),
#  ('Adams', 'male'),
#  ('Addie', 'male'),
#  ('Adger', 'male'),
#  ('Aditya', 'male'),
#  ('Adlai', 'male'),
#  ('Adnan', 'male'),
#  ('Adolf', 'male'),
#  ('Adolfo', 'male'),
#  ('Adolph', 'male'),
#  ('Adolphe', 'male'),
#  ('Adolpho', 'male'),
#  ('Adolphus', 'male'),
#  ('Adrian', 'male'),
#  ('Adrick', 'male'),
#  ('Adrien', 'male'),
#  ('Agamemnon', 'male'),
#  ('Aguinaldo', 'male'),
#  ('Aguste', 'male'),
#  ('Agustin', 'male'),
#  ('Aharon', 'male'),
#  ('Ahmad', 'male'),
#  ('Ahmed', 'male'),
#  ('Ahmet', 'male'),
#  ('Ajai', 'male'),
# ...

# %%
import random
random.shuffle(labeled_names)

# %%
labeled_names
# Out:
# [('Lorna', 'female'),
#  ('Silvain', 'male'),
#  ('Freddi', 'female'),
#  ('Nestor', 'male'),
#  ('Amara', 'female'),
#  ('Aridatha', 'female'),
#  ('Flower', 'female'),
#  ('Jodi', 'male'),
#  ('Britte', 'female'),
#  ('Ansley', 'female'),
#  ('Nigel', 'male'),
#  ('Eada', 'female'),
#  ('Salim', 'male'),
#  ('Clementine', 'female'),
#  ('Kariotta', 'female'),
#  ('Ariel', 'male'),
#  ('Vernice', 'female'),
#  ('Trudey', 'female'),
#  ('Norma', 'female'),
#  ('Bellamy', 'female'),
#  ('Jenda', 'female'),
#  ('Amity', 'female'),
#  ('Jazmin', 'female'),
#  ('Steffi', 'female'),
#  ('Kingsly', 'male'),
#  ('Anna', 'female'),
#  ('Saundra', 'male'),
#  ('Arron', 'male'),
#  ('Dyna', 'female'),
#  ('Tessy', 'female'),
#  ('Garold', 'male'),
#  ('Paton', 'male'),
#  ('Brooke', 'female'),
#  ('Aida', 'female'),
#  ('Lorrayne', 'female'),
#  ('Joni', 'female'),
#  ('Mab', 'female'),
#  ('Henrique', 'male'),
#  ('Quill', 'male'),
#  ('Berta', 'female'),
#  ('Hunt', 'male'),
# ...

# %%
featuresets=[(gender_features(n),gender) for (n,gender) in labeled_names]

# %%
featuresets
# Out:
# [({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'i'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'male'),
# ...

# %%
train_set, test_set = featuresets[500:],featuresets[:500]

# %%
import nltk
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Gargi'))
# Out:
# 'female'

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.784

# %% [markdown]
# ## Tweet Tokeniser

# %%
import nltk

# %%
from nltk.tokenize import TweetTokenizer
text='The Party was so fun 😊😊😊:D #funthings'
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'Party', 'was', 'so', 'fun', '😊', '😊', '😊', ':D', '#funthings']

# %% [markdown]
# ## Assignement:
# Explore COCA
# Demonstrate any three of the five features
# ### Find the frequency count of a word
# ### Chart - word - frequency; section;sub-section;year
# ### Collocate - Display three collocations on the left and right of each of the word
